# %% [markdown]
# ##  Peer Graded Assignment Tools for Data Science

# %% [markdown]
# In this assignment, we will explore various tools used in the field of data science to analyze, process, and visualize data.

# %% [markdown]
# #### Data Science Languages as follows:
# 1. Python
# 2. R
# 3. SQL
# 4. Julia
# 5. Scala
# 6. Java
# 7. C++

# %% [markdown]
# #### Data Science Libraries as follows:
# 1. Pandas
# 2. NumPy
# 3. Matplotlib
# 4. Seaborn
# 5. Scikit-learn
# 6. Keras
# 7. ggplot2

# %% [markdown]
# #### Data Science Tools as follows:
# 1. Jupyter Notebook
# 2. Rstudio
# 3. PowerBI, Tableau, IBM Watson studio
# 4. <b>Libraries:</b> Pandas, NumPy, Matplotlib, Seaborn, Scikit-learn, Keras, ggplot2
# 5. <b>Frameworks:</b> Tensorflow, Apache Spark, Hadoop, PyTorch.
# 6. <b>Databases:</b> MySQL, PostgreSQL, MongoDB, Apache, CouchDB.

# %% [markdown]
# Arithmetic expressions are mathematical equations that consist of numbers, operators, and variables, we will explore various examples of arithmetic expressions.

# %%
n1 = 3
n2 = 5

# Multiplying two integers
product = n1 * n2

# Adding two integers
sum = n1 + n2

# Printing the result
print("Multiplication is:", product)
print("Addition is:", sum)
# Out:
# Multiplication is: 15
# Addition is: 8

# %%
hours = 3

# Converting hours to minutes
minutes = hours * 60

# Printing the result
print(hours, "hours is equal to", minutes, "minutes.")
# Out:
# 3 hours is equal to 180 minutes.

# %% [markdown]
# ### Example of an Unordered List
# In this example, we will create an unordered list of some of the most popular programming languages:
#
# - Python
# - R
# - SQL
# - Julia
# - Java
# - C++
# - MATLAB

# %% [markdown]
# #### Author - Aditya Survase
